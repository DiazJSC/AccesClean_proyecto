# %% [markdown]
# # Universidad Libre - Seccional Cali<br>Facultad de Ingeniería - Diplomado en Ciencia de Datos<br>(ↄ) Juan Sebastian Diaz Campos, 2026
#
# # 00_descargas
# En esta plantilla entregada por el profesor Diego Fernando Marin se llevará a cabo el desarrollo del proyecto del diplomado de Ciencia de Datos, aplicando buenas prácticas.
#
# ---

# %% [markdown]
# Este cuaderno representa el primer paso crucial en nuestro proceso de ciencia de datos: la obtención y almacenamiento de datos crudos. El principio fundamental aquí es preservar los datos en su estado original, sin modificaciones, para garantizar la reproducibilidad del análisis y mantener una referencia histórica confiable.
#
# **Propósito:** Establecer el punto de partida del análisis mediante la recopilación y almacenamiento de datos crudos de múltiples fuentes, manteniendo la integridad y trazabilidad de la información original.
#
# **Tareas a realizar:**
# - Extración de los Datasets de Recursos Humano desde carpeta compartida
# - Extración de los Datasets de Matriz de Roles VS Cargos desde carpeta compartida
# - Extración de los Datasets de Reporte Humanos desde carpeta compartida
# - Extración de los Datasets de Recursos Solicitudes revisidas al Portal desde carpeta compartida

# %%
# Librerías a utilizar en este módulo
import os
from pathlib import Path
import shutil

# %%
cwd = os.getcwd() # current working directory
raw_dir = cwd + '/../data/raw/' # aquí deben quedar los archivos 'crudos'

# %%
os.listdir(raw_dir)
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'aplicaciones',
#  'matrices',
#  'rrhh',
#  'solicitudes']

# %% [markdown]
# ## Extracción datos de carpeta compartida - Dataset Recursos Humanos

# %%
ORIGEN = Path(r"A:\Universidad\AccesClean\RecursosHumanos")
DESTINO = Path(raw_dir + 'rrhh')

for archivo in ORIGEN.glob("*.xlsx"):
    print("[1] Archivo(s) a copiar en carpeta: "+archivo.name)
    
    if archivo.name.startswith("~$"):
        print("[2] Archivo temporal ignorado: "+archivo.name)
        continue
        
    shutil.copy2(archivo, DESTINO)
    print("[3] Archivo(s) copiados exitosamente en destino: "+archivo.name)
# Out:
# [1] Archivo(s) a copiar en carpeta: 1 - HAM_24_Acuerdo_Empleados_Activos.xlsx
# [3] Archivo(s) copiados exitosamente en destino: 1 - HAM_24_Acuerdo_Empleados_Activos.xlsx
# [1] Archivo(s) a copiar en carpeta: Colaboradores Migrados a IDM.xlsx
# [3] Archivo(s) copiados exitosamente en destino: Colaboradores Migrados a IDM.xlsx
# [1] Archivo(s) a copiar en carpeta: ~$1 - HAM_24_Acuerdo_Empleados_Activos.xlsx
# [2] Archivo temporal ignorado: ~$1 - HAM_24_Acuerdo_Empleados_Activos.xlsx
# [1] Archivo(s) a copiar en carpeta: ~$Colaboradores Migrados a IDM.xlsx
# [2] Archivo temporal ignorado: ~$Colaboradores Migrados a IDM.xlsx

# %%
# !dir ..\data\raw\rrhh
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: AAF0-D5E8
#
#  Directorio de C:\Users\Juan S. Diaz\AccesClean_proyecto\data\raw\rrhh
#
# 19/06/2026  11:18p.ÿm.    <DIR>          .
# 19/06/2026  11:20p.ÿm.    <DIR>          ..
# 19/06/2026  08:33p.ÿm.           100.744 1 - HAM_24_Acuerdo_Empleados_Activos.xlsx
# 05/07/2026  01:16p.ÿm.            70.727 Colaboradores Migrados a IDM.xlsx
#                2 archivos        171.471 bytes
#                2 dirs  65.780.285.440 bytes libres

# %% [markdown]
# ## Extracción datos de carpeta compartida - Dataset Matrices Roles y Perfiles

# %%
ORIGEN = Path(r"A:\Universidad\AccesClean\Matrices")
DESTINO = Path(raw_dir + 'matrices')

for archivo in ORIGEN.glob("*.xlsx"):
    print("[1] Archivo(s) a copiar en carpeta: "+archivo.name)
    
    if archivo.name.startswith("~$"):
        print("[2] Archivo temporal ignorado: "+archivo.name)
        continue
        
    shutil.copy2(archivo, DESTINO)
    print("[3] Archivo(s) copiados exitosamente en destino: "+archivo.name)
# Out:
# [1] Archivo(s) a copiar en carpeta: Matriz Roles y Perfiles AdminBusiness V8.xlsx
# [3] Archivo(s) copiados exitosamente en destino: Matriz Roles y Perfiles AdminBusiness V8.xlsx

# %%
# !dir ..\data\raw\matrices
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: AAF0-D5E8
#
#  Directorio de C:\Users\Juan S. Diaz\AccesClean_proyecto\data\raw\matrices
#
# 19/06/2026  11:20p.ÿm.    <DIR>          .
# 19/06/2026  11:20p.ÿm.    <DIR>          ..
# 19/06/2026  09:27p.ÿm.            16.248 Matriz Roles y Perfiles AdminBusiness V8.xlsx
#                1 archivos         16.248 bytes
#                2 dirs  65.780.477.952 bytes libres

# %% [markdown]
# ## Extracción datos de carpeta compartida - Dataset Reporte Aplicación

# %%
ORIGEN = Path(r"A:\Universidad\AccesClean\Apps")
DESTINO = Path(raw_dir + 'aplicaciones')

for archivo in ORIGEN.glob("*"):
    print("[1] Archivo(s) a copiar en carpeta: "+archivo.name)
    
    if archivo.name.startswith("~$"):
        print("[2] Archivo temporal ignorado: "+archivo.name)
        continue
        
    shutil.copy2(archivo, DESTINO)
    print("[3] Archivo(s) copiados exitosamente en destino: "+archivo.name)
# Out:
# [1] Archivo(s) a copiar en carpeta: report_users_profile_accesclean_2026_05.csv
# [3] Archivo(s) copiados exitosamente en destino: report_users_profile_accesclean_2026_05.csv
# [1] Archivo(s) a copiar en carpeta: report_users_profile_accesclean_2026_06.csv
# [3] Archivo(s) copiados exitosamente en destino: report_users_profile_accesclean_2026_06.csv

# %%
# !dir ..\data\raw\aplicaciones
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: AAF0-D5E8
#
#  Directorio de C:\Users\Juan S. Diaz\AccesClean_proyecto\data\raw\aplicaciones
#
# 05/07/2026  02:50p.ÿm.    <DIR>          .
# 19/06/2026  11:20p.ÿm.    <DIR>          ..
# 05/07/2026  02:50p.ÿm.    <DIR>          .ipynb_checkpoints
# 05/07/2026  02:45p.ÿm.            15.403 report_users_profile_accesclean_2026_05.csv
# 05/07/2026  02:46p.ÿm.            15.771 report_users_profile_accesclean_2026_06.csv
#                2 archivos         31.174 bytes
#                3 dirs  65.780.477.952 bytes libres

# %% [markdown]
# ## Extracción datos de carpeta compartida - Dataset Solicitudes Realizadas

# %%
ORIGEN = Path(r"A:\Universidad\AccesClean\Solicitudes")
DESTINO = Path(raw_dir + 'solicitudes')

for archivo in ORIGEN.glob("*"):
    print("[1] Archivo(s) a copiar en carpeta: "+archivo.name)
    
    if archivo.name.startswith("~$"):
        print("[2] Archivo temporal ignorado: "+archivo.name)
        continue
        
    shutil.copy2(archivo, DESTINO)
    print("[3] Archivo(s) copiados exitosamente en destino: "+archivo.name)
# Out:
# [1] Archivo(s) a copiar en carpeta: solicitudes_jsdiaz_2025.csv
# [3] Archivo(s) copiados exitosamente en destino: solicitudes_jsdiaz_2025.csv
# [1] Archivo(s) a copiar en carpeta: solicitudes_jsdiaz_2026.csv
# [3] Archivo(s) copiados exitosamente en destino: solicitudes_jsdiaz_2026.csv
# [1] Archivo(s) a copiar en carpeta: solicitudes_jzamorano_2024.csv
# [3] Archivo(s) copiados exitosamente en destino: solicitudes_jzamorano_2024.csv
# [1] Archivo(s) a copiar en carpeta: solicitudes_jzamorano_2025.csv
# [3] Archivo(s) copiados exitosamente en destino: solicitudes_jzamorano_2025.csv
# [1] Archivo(s) a copiar en carpeta: solicitudes_mrodriguezpe_2024.csv
# [3] Archivo(s) copiados exitosamente en destino: solicitudes_mrodriguezpe_2024.csv
# [1] Archivo(s) a copiar en carpeta: solicitudes_mrodriguezpe_2025.csv
# [3] Archivo(s) copiados exitosamente en destino: solicitudes_mrodriguezpe_2025.csv
# [1] Archivo(s) a copiar en carpeta: solicitudes_mrodriguezpe_2026.csv
# ...

# %%
# !dir ..\data\raw\solicitudes
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: AAF0-D5E8
#
#  Directorio de C:\Users\Juan S. Diaz\AccesClean_proyecto\data\raw\solicitudes
#
# 17/07/2026  07:08p.ÿm.    <DIR>          .
# 19/06/2026  11:20p.ÿm.    <DIR>          ..
# 15/07/2026  11:13p.ÿm.            60.457 solicitudes_jsdiaz_2025.csv
# 15/07/2026  11:13p.ÿm.           156.952 solicitudes_jsdiaz_2026.csv
# 15/07/2026  11:13p.ÿm.            66.482 solicitudes_jzamorano_2024.csv
# 15/07/2026  11:13p.ÿm.           272.067 solicitudes_jzamorano_2025.csv
# 15/07/2026  11:13p.ÿm.           181.460 solicitudes_mrodriguezpe_2024.csv
# 15/07/2026  11:13p.ÿm.           119.837 solicitudes_mrodriguezpe_2025.csv
# 15/07/2026  11:13p.ÿm.            37.812 solicitudes_mrodriguezpe_2026.csv
#                7 archivos        895.067 bytes
#                2 dirs  65.780.056.064 bytes libres
